# %%
import pandas as pd

# %%
df=pd.read_csv('usagers-2022.csv',sep=';')
df.head()
# Out:
#         Num_Acc  id_usager id_vehicule num_veh  place  catu  grav  sexe  \
# 0  202200000001  1 099 700     813 952     A01      1     1     3     1
# 1  202200000001  1 099 701     813 953     B01      1     1     1     1
# 2  202200000002  1 099 698     813 950     B01      1     1     4     1
# 3  202200000002  1 099 699     813 951     A01      1     1     1     1
# 4  202200000003  1 099 696     813 948     A01      1     1     1     1
#
#    an_nais  trajet  secu1  secu2  secu3  locp actp  etatp
# 0   2008.0       5      2      8     -1    -1   -1     -1
# 1   1948.0       5      1      8     -1    -1   -1     -1
# 2   1988.0       9      1      0     -1     0    0     -1
# 3   1970.0       4      1      0     -1     0    0     -1
# 4   2002.0       0      1      0     -1    -1   -1     -1

# %%
import numpy as np

# %%
import matplotlib as plt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import matplotlib as plt
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
conda install matplotlib
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: c:\ProgramData\Anaconda3\envs\test56
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-1.0.9               |       h2bbff1b_8          19 KB
#     brotli-bin-1.0.9           |       h2bbff1b_8          29 KB
#     fonttools-4.51.0           |   py38h2bbff1b_0         2.0 MB
#     lcms2-2.12                 |       h83e58a3_0         454 KB
#     libbrotlicommon-1.0.9      |       h2bbff1b_8          79 KB
#     libbrotlidec-1.0.9         |       h2bbff1b_8          39 KB
#     libbrotlienc-1.0.9         |       h2bbff1b_8         261 KB
#     lz4-c-1.9.4                |       h2bbff1b_1         152 KB
#     matplotlib-3.7.2           |   py38haa95532_0           9 KB
#     pillow-10.3.0              |   py38h2bbff1b_0         837 KB
#     unicodedata2-15.1.0        |   py38h2bbff1b_0         525 KB
#     xz-5.4.6                   |       h8cc25b3_1         609 KB
#     zlib-1.2.13                |       h8cc25b3_1         131 KB
#     zstd-1.5.5                 |       hd43e919_1         694 KB
#     ------------------------------------------------------------
#                                            Total:         5.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli             pkgs/main/win-64::brotli-1.0.9-h2bbff1b_8
#   brotli-bin         pkgs/main/win-64::brotli-bin-1.0.9-h2bbff1b_8
#   contourpy          pkgs/main/win-64::contourpy-1.0.5-py38h59b6b97_0
#   cycler             pkgs/main/noarch::cycler-0.11.0-pyhd3eb1b0_0
#   fonttools          pkgs/main/win-64::fonttools-4.51.0-py38h2bbff1b_0
#   freetype           pkgs/main/win-64::freetype-2.12.1-ha860e81_0
#   icu                pkgs/main/win-64::icu-73.1-h6c2663c_0
#   jpeg               pkgs/main/win-64::jpeg-9e-h2bbff1b_1
#   kiwisolver         pkgs/main/win-64::kiwisolver-1.4.4-py38hd77b12b_0
#   krb5               pkgs/main/win-64::krb5-1.20.1-h5b6d351_0
#   lcms2              pkgs/main/win-64::lcms2-2.12-h83e58a3_0
#   lerc               pkgs/main/win-64::lerc-3.0-hd77b12b_0
#   libbrotlicommon    pkgs/main/win-64::libbrotlicommon-1.0.9-h2bbff1b_8
#   libbrotlidec       pkgs/main/win-64::libbrotlidec-1.0.9-h2bbff1b_8
#   libbrotlienc       pkgs/main/win-64::libbrotlienc-1.0.9-h2bbff1b_8
#   libclang           pkgs/main/win-64::libclang-14.0.6-default_hb5a9fac_1
#   libclang13         pkgs/main/win-64::libclang13-14.0.6-default_h8e68704_1
#   libdeflate         pkgs/main/win-64::libdeflate-1.17-h2bbff1b_1
#   libpng             pkgs/main/win-64::libpng-1.6.39-h8cc25b3_0
#   libpq              pkgs/main/win-64::libpq-12.17-h906ac69_0
#   libtiff            pkgs/main/win-64::libtiff-4.5.1-hd77b12b_0
#   libwebp-base       pkgs/main/win-64::libwebp-base-1.3.2-h2bbff1b_0
#   lz4-c              pkgs/main/win-64::lz4-c-1.9.4-h2bbff1b_1
#   matplotlib         pkgs/main/win-64::matplotlib-3.7.2-py38haa95532_0
#   matplotlib-base    pkgs/main/win-64::matplotlib-base-3.7.2-py38h4ed8f06_0
#   openjpeg           pkgs/main/win-64::openjpeg-2.4.0-h4fc8c34_0
#   pillow             pkgs/main/win-64::pillow-10.3.0-py38h2bbff1b_0
#   ply                pkgs/main/win-64::ply-3.11-py38_0
#   pyparsing          pkgs/main/win-64::pyparsing-3.0.9-py38haa95532_0
#   pyqt               pkgs/main/win-64::pyqt-5.15.10-py38hd77b12b_0
#   pyqt5-sip          pkgs/main/win-64::pyqt5-sip-12.13.0-py38h2bbff1b_0
#   qt-main            pkgs/main/win-64::qt-main-5.15.2-h19c9488_10
#   sip                pkgs/main/win-64::sip-6.7.12-py38hd77b12b_0
#   unicodedata2       pkgs/main/win-64::unicodedata2-15.1.0-py38h2bbff1b_0
#   xz                 pkgs/main/win-64::xz-5.4.6-h8cc25b3_1
#   zlib               pkgs/main/win-64::zlib-1.2.13-h8cc25b3_1
#   zstd               pkgs/main/win-64::zstd-1.5.5-hd43e919_1
#
#
#
# Downloading and Extracting Packages
#
# pillow-10.3.0        | 837 KB    |            |   0%
# pillow-10.3.0        | 837 KB    | 1          |   2%
# pillow-10.3.0        | 837 KB    | ###        |  31%
# pillow-10.3.0        | 837 KB    | #########9 |  99%
# pillow-10.3.0        | 837 KB    | ########## | 100%
#
# zstd-1.5.5           | 694 KB    |            |   0%
# zstd-1.5.5           | 694 KB    | 2          |   2%
# zstd-1.5.5           | 694 KB    | ########## | 100%
# zstd-1.5.5           | 694 KB    | ########## | 100%
#
# libbrotlicommon-1.0. | 79 KB     |            |   0%
# libbrotlicommon-1.0. | 79 KB     | ########## | 100%
# libbrotlicommon-1.0. | 79 KB     | ########## | 100%
#
# unicodedata2-15.1.0  | 525 KB    |            |   0%
# unicodedata2-15.1.0  | 525 KB    | ####8      |  49%
# unicodedata2-15.1.0  | 525 KB    | ########## | 100%
#
# lcms2-2.12           | 454 KB    |            |   0%
# lcms2-2.12           | 454 KB    | ####2      |  42%
# lcms2-2.12           | 454 KB    | ########## | 100%
#
# matplotlib-3.7.2     | 9 KB      |            |   0%
# matplotlib-3.7.2     | 9 KB      | ########## | 100%
# matplotlib-3.7.2     | 9 KB      | ########## | 100%
#
# fonttools-4.51.0     | 2.0 MB    |            |   0%
# fonttools-4.51.0     | 2.0 MB    |            |   1%
# fonttools-4.51.0     | 2.0 MB    | #######    |  70%
# fonttools-4.51.0     | 2.0 MB    | ########## | 100%
# fonttools-4.51.0     | 2.0 MB    | ########## | 100%
#
# lz4-c-1.9.4          | 152 KB    |            |   0%
# lz4-c-1.9.4          | 152 KB    | ########## | 100%
# lz4-c-1.9.4          | 152 KB    | ########## | 100%
#
# zlib-1.2.13          | 131 KB    |            |   0%
# zlib-1.2.13          | 131 KB    | ########## | 100%
# zlib-1.2.13          | 131 KB    | ########## | 100%
#
# libbrotlidec-1.0.9   | 39 KB     |            |   0%
# libbrotlidec-1.0.9   | 39 KB     | ########## | 100%
# libbrotlidec-1.0.9   | 39 KB     | ########## | 100%
#
# xz-5.4.6             | 609 KB    |            |   0%
# xz-5.4.6             | 609 KB    | ##3        |  24%
# xz-5.4.6             | 609 KB    | ########## | 100%
# xz-5.4.6             | 609 KB    | ########## | 100%
#
# brotli-bin-1.0.9     | 29 KB     |            |   0%
# brotli-bin-1.0.9     | 29 KB     | ########## | 100%
# brotli-bin-1.0.9     | 29 KB     | ########## | 100%
#
# libbrotlienc-1.0.9   | 261 KB    |            |   0%
# libbrotlienc-1.0.9   | 261 KB    | ########5  |  86%
# libbrotlienc-1.0.9   | 261 KB    | ########## | 100%
#
# brotli-1.0.9         | 19 KB     |            |   0%
# brotli-1.0.9         | 19 KB     | ########3  |  83%
# brotli-1.0.9         | 19 KB     | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.9.2
#   latest version: 24.4.0
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda

# %%
import matplotlib as plt
